# %% [markdown]
# # Analysis of the covid moonshot rationale
# `COVID_moonshot_submissions` folder is the gitrepo https://github.com/postera-ai/COVID_moonshot_submissions

# %%
gitrepo_folder = 'textual-analysis-of-COVID-Moonshot'

# %%
import os

import pandas as pd

submission_filename = '../COVID_moonshot_submissions/covid_submissions_all_info.csv'

postera = pd.read_csv(submission_filename)
# Out:
# /Users/matteo/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (3,19,29,30,31,32,33,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# the table contains multiple rows/submitted compounds per submission.
# Say the CID `ANT-DIA-3c79be55-1` finishes in `-1`
postera = postera.assign(CID_group=postera.CID.str.extract(r'(.*)\-\d+'))
minpostera = postera.drop_duplicates('CID_group')

# %% [markdown]
# ## Bag of words
#
# Making a bag of words for a word cloud and to see which terms are enriched

# %%
import re
from collections import Counter

word_block = ' '.join(minpostera.rationale) + ' '.join(minpostera['Submission Notes'].astype(str))
word_block = word_block.replace('by eye', 'by-eye').replace("n't", '')
words = re.findall('[\w\-]+', word_block.lower())
wordbag = Counter(words)

# %%
wordbag['fragalysis']
# Out:
# 21

# %%
# common words (`the`, `of` etc.) need to be remove from the wordbag

import requests

r = requests.get('https://gist.githubusercontent.com/deekayen/4148741/raw/98d35708fa344717d8eee15d11987de6c8e26d7d/1-1000.txt')

common_words = set(r.text.split('\n')) - {'molecule', 'machine', 'dock', 'learn'}

# shoddy way of expanding it.
# `againsted` is not a real word, but it's presence does not harm anyone.
expanded_common_words = set(list(common_words) + \
                            [w+'s' for w in common_words] + \
                            [w+'es' for w in common_words] + \
                            [w+'ed' for w in common_words] + \
                            [w+'ing' for w in common_words] + \
                            [w+'ly' for w in common_words] + \
                            ['http', 'https', 'com', 'org', 'www']
                           )

# %%
## remove them

for k in expanded_common_words.intersection(wordbag.keys()):
    del wordbag[k]
    
for k in list(wordbag.keys()):
    if k.isdigit() or len(k) < 3:
        del wordbag[k]

# %%
wordbag.most_common()
# Out:
# [('nan', 1061),
#  ('fragments', 446),
#  ('compounds', 443),
#  ('molecules', 385),
#  ('fragment', 367),
#  ('docking', 326),
#  ('structure', 325),
#  ('binding', 304),
#  ('based', 271),
#  ('pocket', 249),
#  ('structures', 242),
#  ('bond', 226),
#  ('molecule', 210),
#  ('hydrogen', 192),
#  ('covalent', 189),
#  ('crystal', 188),
#  ('compound', 181),
#  ('into', 177),
#  ('site', 176),
#  ('by-eye', 173),
#  ('enamine', 169),
#  ('ligand', 167),
#  ('docked', 164),
#  ('pdb', 156),
#  ('available', 153),
#  ('protein', 147),
#  ('screening', 147),
#  ('interaction', 138),
#  ('interactions', 129),
#  ('library', 129),
#  ('non-covalent', 128),
#  ('synthesis', 127),
#  ('active', 125),
#  ('protease', 119),
#  ('activity', 118),
#  ('predictions', 113),
#  ('molecular', 110),
#  ('domain', 109),
#  ('model', 107),
#  ('generated', 106),
#  ('amide', 104),
#  ('applicability', 104),
#  ('predicted', 102),
#  ('affinity', 100),
#  ('different', 92),
#  ('module', 92),
#  ('stages', 92),
#  ('seesar', 87),
#  ('per', 86),
#  ('residues', 85),
#  ('further', 84),
#  ('linking', 84),
#  ('software', 84),
#  ('submitted', 83),
#  ('properties', 82),
#  ('drug', 81),
#  ('submission', 81),
#  ('performed', 81),
#  ('inhibitors', 80),
#  ('warhead', 80),
#  ('scaffold', 79),
#  ('bonds', 78),
#  ('mpro', 78),
#  ('ligands', 77),
#  ('algorithm', 76),
#  ('series', 74),
#  ('chemistry', 74),
#  ('functional', 73),
#  ('pharmacophore', 71),
#  ('inhibitor', 70),
#  ('approach', 70),
#  ('probes', 70),
#  ('rotatable', 69),
#  ('x0434', 64),
#  ('merging', 64),
#  ('analogues', 63),
#  ('structure-based', 63),
#  ('consideration', 63),
#  ('combination', 62),
#  ('additional', 62),
#  ('pyridine', 62),
#  ('mol', 62),
#  ('6lu7', 62),
#  ('cluster', 61),
#  ('bind', 61),
#  ('diamond', 61),
#  ('scoring', 61),
#  ('-number', 60),
#  ('aromatic', 59),
#  ('nitrogen', 59),
#  ('target', 59),
#  ('cysteine', 58),
#  ('potential', 58),
#  ('moiety', 57),
#  ('h-bond', 57),
#  ('acceptors', 57),
#  ('calculated', 57),
#  ('backbone', 56),
#  ('account', 56),
#  ('kcal', 56),
#  ('x0104', 55),
#  ('inspired', 55),
#  ('chain', 55),
#  ('reu', 55),
#  ('virtual', 55),
#  ('glidesp', 54),
#  ('vina', 53),
#  ('donors', 53),
#  ('medicinal', 53),
#  ('doi', 52),
#  ('piperazine', 51),
#  ('initial', 51),
#  ('chemical', 51),
#  ('conformation', 50),
#  ('x-ray', 50),
#  ('sars-cov-2', 50),
#  ('selection', 50),
#  ('automatically', 50),
#  ('identified', 49),
#  ('bound', 49),
#  ('function', 49),
#  ('observed', 49),
#  ('carbonyl', 49),
#  ('obtained', 49),
#  ('database', 49),
#  ('sar', 48),
#  ('synthetic', 48),
#  ('nitrile', 47),
#  ('glu166', 47),
#  ('scored', 47),
#  ('file', 47),
#  ('collection', 47),
#  ('libraries', 47),
#  ('urea', 46),
#  ('increase', 46),
#  ('qsb', 46),
#  ('core', 45),
#  ('centre', 45),
#  ('penalty', 45),
#  ('interacting', 45),
#  ('drugs', 45),
#  ('treweren', 45),
#  ('x0072', 44),
#  ('hydrophobic', 44),
#  ('programs', 44),
#  ('because', 43),
#  ('filter', 43),
#  ('desolvation', 43),
#  ('known', 42),
#  ('geometry', 42),
#  ('binding-site', 42),
#  ('x0678', 41),
#  ('substituent', 41),
#  ('files', 40),
#  ('structural', 39),
#  ('attached', 39),
#  ('covid-19', 39),
#  ('combo', 39),
#  ('calculations', 39),
#  ('analysis', 38),
#  ('built', 38),
#  ('derivatives', 38),
#  ('methyl', 38),
#  ('substituents', 38),
#  ('x1093', 37),
#  ('sulfonamide', 37),
#  ('profile', 37),
#  ('postera', 37),
#  ('source', 37),
#  ('taking', 37),
#  ('previous', 37),
#  ('x0305', 36),
#  ('within', 36),
#  ('occupy', 36),
#  ('submissions', 36),
#  ('acceptor', 36),
#  ('representative', 36),
#  ('rationale', 36),
#  ('minimization', 36),
#  ('brics', 36),
#  ('phenyl', 35),
#  ('targeting', 35),
#  ('x_0946', 35),
#  ('similarity', 35),
#  ('protein-ligand', 35),
#  ('multiple', 35),
#  ('xlogp', 35),
#  ('xlogs', 35),
#  ('xdg_hyd', 35),
#  ('rs_score_raw', 35),
#  ('rsconvol_score_raw', 35),
#  ('rosettaligandinterfacescore', 35),
#  ('moleculecomplexity', 35),
#  ('fred', 35),
#  ('given', 35),
#  ('enhanced', 35),
#  ('inspirator', 35),
#  ('larger', 35),
#  ('via', 34),
#  ('targeted', 34),
#  ('x_0678', 34),
#  ('prepared', 34),
#  ('around', 33),
#  ('extend', 33),
#  ('commercially', 33),
#  ('von', 33),
#  ('bcl', 33),
#  ('logp', 33),
#  ('tpsa', 33),
#  ('evaluation', 33),
#  ('chemscore', 32),
#  ('approved', 32),
#  ('features', 32),
#  ('complex', 32),
#  ('anthony', 32),
#  ('aimon', 32),
#  ('requiring', 32),
#  ('hydrogens', 32),
#  ('pockets', 31),
#  ('x0195', 31),
#  ('cys145', 31),
#  ('although', 31),
#  ('residue', 31),
#  ('without', 31),
#  ('chloroacetamides', 31),
#  ('reported', 31),
#  ('conformational', 31),
#  ('diverse', 31),
#  ('frank', 31),
#  ('delft', 31),
#  ('lipophilicity', 31),
#  ('rdock', 31),
#  ('explicit', 31),
#  ('tautomers', 31),
#  ('jag-ucb-a3ef7265-20', 31),
#  ('substitution', 30),
#  ('x0107', 30),
#  ('interact', 30),
#  ('combined', 30),
#  ('data', 30),
#  ('optimization', 30),
#  ('network', 30),
#  ('linkers', 30),
#  ('carbon', 30),
#  ('modifications', 30),
#  ('chem', 30),
#  ('threshold', 30),
#  ('completed', 30),
#  ('agreed', 30),
#  ('overlap', 29),
#  ('included', 29),
#  ('potent', 29),
#  ('favorable', 29),
#  ('potency', 29),
#  ('according', 29),
#  ('cavity', 29),
#  ('easy', 28),
#  ('x0770', 28),
#  ('proposed', 28),
#  ('linker', 28),
#  ('reactive', 28),
#  ('targets', 28),
#  ('modification', 28),
#  ('consists', 28),
#  ('x0995', 27),
#  ('formation', 27),
#  ('scaffolds', 27),
#  ('chosen', 27),
#  ('aimed', 27),
#  ('orientation', 27),
#  ('previously', 27),
#  ('acid', 27),
#  ('replace', 27),
#  ('environment', 27),
#  ('sars', 27),
#  ('bonding', 27),
#  ('linked', 27),
#  ('in-house', 27),
#  ('folding', 27),
#  ('aa-001', 27),
#  ('merge', 26),
#  ('combining', 26),
#  ('analogue', 26),
#  ('due', 26),
#  ('extra', 26),
#  ('highest', 26),
#  ('cys', 26),
#  ('another', 26),
#  ('-11', 26),
#  ('acrylamide', 26),
#  ('mapping', 26),
#  ('placeholder', 26),
#  ('expansion', 25),
#  ('addition', 25),
#  ('version', 25),
#  ('reactivity', 25),
#  ('lab', 25),
#  ('modeling', 25),
#  ('modified', 25),
#  ('expert', 25),
#  ('10k', 25),
#  ('partitioned', 25),
#  ('his163', 24),
#  ('taken', 24),
#  ('derived', 24),
#  ('related', 24),
#  ('dnn', 24),
#  ('learning', 24),
#  ('filtered', 24),
#  ('ranking', 24),
#  ('research', 24),
#  ('computational', 24),
#  ('weizmann', 24),
#  ('polar', 23),
#  ('x_0434', 23),
#  ('pyridyl', 23),
#  ('amine', 23),
#  ('primary', 23),
#  ('applied', 23),
#  ('m-pro', 23),
#  ('fda', 23),
#  ('including', 23),
#  ('parallel', 23),
#  ('extension', 23),
#  ('calculation', 23),
#  ('quantum-based', 23),
#  ('builder', 23),
#  ('pharmacophore-based', 23),
#  ('subprogram', 23),
#  ('step-by-step', 23),
#  ('fragmentation', 23),
#  ('consecutive', 23),
#  ('retained', 23),
#  ('5rf3', 23),
#  ('piperidine', 22),
#  ('benzene', 22),
#  ('however', 22),
#  ('improve', 22),
#  ('discovery', 22),
#  ('replaced', 22),
#  ('review', 22),
#  ('antiviral', 22),
#  ('visual', 22),
#  ('reference', 22),
#  ('program', 22),
#  ('bioactive', 22),
#  ('covid', 22),
#  ('focused', 22),
#  ('appropriate', 22),
#  ('application', 22),
#  ('university', 22),
#  ('6y84', 22),
#  ('x1249', 21),
#  ('fragalysis', 21),
#  ('non', 21),
#  ('removed', 21),
#  ('indole', 21),
#  ('therefore', 21),
#  ('inhibition', 21),
#  ('models', 21),
#  ('amino', 21),
#  ('making', 21),
#  ('prediction', 21),
#  ('toxicity', 21),
#  ('michael', 21),
#  ('virus', 21),
#  ('warheads', 21),
#  ('covid19', 21),
#  ('x967', 21),
#  ('fragment-growing', 21),
#  ('openmm', 21),
#  ('sascore', 21),
#  ('analog', 21),
#  ('entropy', 21),
#  ('rcns', 21),
#  ('explore', 20),
#  ('x0161', 20),
#  ('combinations', 20),
#  ('chains', 20),
#  ('m165', 20),
#  ('bonded', 20),
#  ('autodock', 20),
#  ('shown', 20),
#  ('instead', 20),
#  ('glide', 20),
#  ('various', 20),
#  ('inspection', 20),
#  ('x0967', 20),
#  ('ic50', 20),
#  ('molmatinf', 20),
#  ('mio', 20),
#  ('intermediates', 20),
#  ('matt', 20),
#  ('clustering', 20),
#  ('solvation', 20),
#  ('-rosettaligandinterfacescore', 20),
#  ('-rs_score_raw', 20),
#  ('-rsconvol_score_raw', 20),
#  ('-property', 20),
#  ('-xlogp', 20),
#  ('-xlogs', 20),
#  ('-xdg_hyd', 20),
#  ('-moleculecomplexity', 20),
#  ('-additional', 20),
#  ('-weight', 20),
#  ('-tpsa', 20),
#  ('chloro', 19),
#  ('thiophene', 19),
#  ('attempt', 19),
#  ('sulphonamide', 19),
#  ('vector', 19),
#  ('already', 19),
#  ('enzyme', 19),
#  ('sidechain', 19),
#  ('pose-dependent', 19),
#  ('promising', 19),
#  ('heterocyclic', 19),
#  ('project', 19),
#  ('screen', 19),
#  ('intermediate', 19),
#  ('synthesized', 19),
#  ('5r83', 19),
#  ('entire', 19),
#  ('drugscorex', 19),
#  ('hf-3c', 19),
#  ('pcm', 19),
#  ('implicit', 19),
#  ('capped', 19),
#  ('simplistic', 19),
#  ('important', 18),
#  ('covalently', 18),
#  ('phenol', 18),
#  ('flexible', 18),
#  ('chloroacetamide', 18),
#  ('replacement', 18),
#  ('x_0161', 18),
#  ('catalytic', 18),
#  ('simulation', 18),
#  ('enantiomer', 18),
#  ('cc1', 18),
#  ('his41', 18),
#  ('neural', 18),
#  ('rosetta', 18),
#  ('rmsd', 18),
#  ('machine', 18),
#  ('immediately', 18),
#  ('ureido', 18),
#  ('hydrogen-bonding', 18),
#  ('undergoes', 18),
#  ('ids', 18),
#  ('3cl', 18),
#  ('5rf7', 18),
#  ('pyrimidine', 17),
#  ('aim', 17),
#  ('flexibility', 17),
#  ('provided', 17),
#  ('cyclohexyl', 17),
#  ('chiral', 17),
#  ('etc', 17),
#  ('hybrid', 17),
#  ('proximity', 17),
#  ('x_0107', 17),
#  ('x_0195', 17),
#  ('providing', 17),
#  ('substituted', 17),
#  ('amines', 17),
#  ('minimize', 17),
#  ('re-docked', 17),
#  ('novel', 17),
#  ('journal', 17),
#  ('comparison', 17),
#  ('below', 17),
#  ('candidates', 17),
#  ('binders', 17),
#  ('x0397', 17),
#  ('e166', 17),
#  ('detailed', 17),
#  ('inhibit', 17),
#  ('analogs', 17),
#  ('ada-ucb-6c2cb422-1', 17),
#  ('x0387', 16),
#  ('overlay', 16),
#  ('readily', 16),
#  ('alternative', 16),
#  ('halogen', 16),
#  ('easily', 16),
#  ('simply', 16),
#  ('h-bonds', 16),
#  ('imidazoles', 16),
#  ('peptide', 16),
#  ('x0946', 16),
#  ('melatonin', 16),
#  ('derivative', 16),
#  ('email', 16),
#  ('stability', 16),
#  ('ester', 16),
#  ('corresponding', 16),
#  ('ranked', 16),
#  ('basis', 16),
#  ('hiv', 16),
#  ('generate', 16),
#  ('replacements', 16),
#  ('minimized', 16),
#  ('remove', 16),
#  ('proteases', 16),
#  ('accessible', 16),
#  ('institute', 16),
#  ('behalf', 16),
#  ('oxford', 16),
#  ('isoquinoline', 16),
#  ('benzyl', 15),
#  ('coordinates', 15),
#  ('accessibility', 15),
#  ('probably', 15),
#  ('information', 15),
#  ('cyclic', 15),
#  ('his164', 15),
#  ('variation', 15),
#  ('metric', 15),
#  ('slightly', 15),
#  ('simultaneously', 15),
#  ('corresponds', 15),
#  ('rdkit', 15),
#  ('commercial', 15),
#  ('treatment', 15),
#  ('alpha', 15),
#  ('x72', 15),
#  ('reaction', 15),
#  ('6y2e', 15),
#  ('m49', 15),
#  ('quinolone', 15),
#  ('x107', 15),
#  ('chromones', 15),
#  ('electrophiles', 15),
#  ('cyanopyrimidines', 15),
#  ('cyanoimidazoles', 15),
#  ('initiating', 15),
#  ('catalogue', 15),
#  ('pyrimidines', 15),
#  ('györgy', 15),
#  ('miklós', 15),
#  ('keserű', 15),
#  ('facilities', 15),
#  ('mode', 14),
#  ('coupling', 14),
#  ('x0692', 14),
#  ('studies', 14),
#  ('reduce', 14),
#  ('gln189', 14),
#  ('lipophilic', 14),
#  ('seen', 14),
#  ('combine', 14),
#  ('variations', 14),
#  ('contact', 14),
#  ('solubility', 14),
#  ('inspiration', 14),
#  ('aiming', 14),
#  ('asn142', 14),
#  ('benjamin', 14),
#  ('meiler', 14),
#  ('protocol', 14),
#  ('focusedlibrarydesign', 14),
#  ('uploaded', 14),
#  ('otava', 14),
#  ('created', 14),
#  ('filtering', 14),
#  ('viral', 14),
#  ('chembl', 14),
#  ('examined', 14),
#  ('asn', 14),
#  ('nitrogens', 14),
#  ('n142', 14),
#  ('candidate', 14),
#  ('lactam', 14),
#  ('hence', 14),
#  ('moonshot', 14),
#  ('-12', 14),
#  ('racemate', 14),
#  ('overall', 14),
#  ('cysteine145', 14),
#  ('batch', 14),
#  ('hts', 14),
#  ('maybe', 13),
#  ('x0874', 13),
#  ('overlapping', 13),
#  ('possibly', 13),
#  ('solvent', 13),
#  ('triazole', 13),
#  ('along', 13),
#  ('conserved', 13),
#  ('exploration', 13),
#  ('clinical', 13),
#  ('tanimoto', 13),
#  ('gly143', 13),
#  ('attempting', 13),
#  ('terminal', 13),
#  ('edu', 13),
#  ('functions', 13),
#  ('reasonably', 13),
#  ('converted', 13),
#  ('binds', 13),
#  ('frags', 13),
#  ('criteria', 13),
#  ('sars-cov', 13),
#  ('noncovalent', 13),
#  ('nicely', 13),
#  ('van', 13),
#  ('higher', 13),
#  ('upon', 13),
#  ('tyrosine54', 13),
#  ('n-methyl', 13),
#  ('incorporating', 12),
#  ('motifs', 12),
#  ('easier', 12),
#  ('amides', 12),
#  ('contacts', 12),
#  ('manually', 12),
#  ('optimisation', 12),
#  ('alkyl', 12),
#  ('fluorine', 12),
#  ('alignment', 12),
#  ('template', 12),
#  ('receptor', 12),
#  ('placed', 12),
#  ('almost', 12),
#  ('combinatorial', 12),
#  ('rosettaligand', 12),
#  ('preparation', 12),
#  ('conformations', 12),
#  ('merges', 12),
#  ('goal', 12),
#  ('described', 12),
#  ('4yoj', 12),
#  ('proteins', 12),
#  ('specific', 12),
#  ('bioorganic', 12),
#  ('pi-pi', 12),
#  ('6yb7', 12),
#  ('csm-lig', 12),
#  ('github', 12),
#  ('selectivity', 12),
#  ('native', 12),
#  ('cavities', 12),
#  ('pharmit', 12),
#  ('ace2', 12),
#  ('ugi', 12),
#  ('desirable', 12),
#  ('histidine162', 12),
#  ('cyclopropyl', 12),
#  ('collaboration', 12),
#  ('constructed', 12),
#  ('akos', 12),
#  ('nc1c', 12),
#  ('jeriek', 12),
#  ('den', 12),
#  ('abeele', 12),
#  ('reactions', 11),
#  ('x1382', 11),
#  ('adjacent', 11),
#  ('exposed', 11),
#  ('request', 11),
#  ('structure-guided', 11),
#  ('interface', 11),
#  ('required', 11),
#  ('route', 11),
#  ('niclosamide', 11),
#  ('h163', 11),
#  ('complexes', 11),
#  ('x0991', 11),
#  ('fingerprint', 11),
#  ('refined', 11),
#  ('synthesize', 11),
#  ('chose', 11),
#  ('predict', 11),
#  ('ritonavir', 11),
#  ('h-bonding', 11),
#  ('resolution', 11),
#  ('manual', 11),
#  ('relationship', 11),
#  ('cleft', 11),
#  ('angstroms', 11),
#  ('positive', 11),
#  ('independently', 11),
#  ('mentioned', 11),
#  ('xchem', 11),
#  ('tried', 11),
#  ('nh2', 11),
#  ('potentially', 11),
#  ('promote', 11),
#  ('main-chain', 11),
#  ('identify', 11),
#  ('3clpro', 11),
#  ('assay', 11),
#  ('effective', 11),
#  ('sorted', 11),
#  ('transition', 11),
#  ('relevant', 11),
#  ('stabilize', 11),
#  ('obtain', 11),
#  ('mandatory', 11),
#  ('chemspace', 11),
#  ('london', 11),
#  ('react', 11),
#  ('try-uni-714a760b-6', 11),
#  ('flavonoid', 11),
#  ('c1cncnc1', 11),
#  ('ucb', 11),
#  ('x10324', 11),
#  ('benzotriazole', 11),
#  ('6wnp', 11),
#  ('vla-ucb-1dbca3b4-15', 11),
#  ('x0830', 10),
#  ('pymol', 10),
#  ('merged', 10),
#  ('compared', 10),
#  ('viewer', 10),
#  ('motif', 10),
#  ('3-pyridine', 10),
#  ('moieties', 10),
#  ('biorxiv', 10),
#  ('content', 10),
#  ('substructures', 10),
#  ('attempted', 10),
#  ('exploring', 10),
#  ('trials', 10),
#  ('defined', 10),
#  ('activities', 10),
#  ('sulfoximine', 10),
#  ('patients', 10),
#  ('constrained', 10),
#  ('substrate', 10),
#  ('lopinavir', 10),
#  ('stacking', 10),
#  ('stable', 10),
#  ('utilized', 10),
#  ('undergo', 10),
#  ('structure-activity', 10),
#  ('-log', 10),
#  ('x1392', 10),
#  ('onto', 10),
#  ('complementarity', 10),
#  ('identical', 10),
#  ('generative', 10),
#  ('computed', 10),
#  ('retaining', 10),
#  ('physchem', 10),
#  ('grown', 10),
#  ('downloaded', 10),
#  ('additionally', 10),
#  ('distances', 10),
#  ('donor', 10),
#  ('phe140', 10),
#  ('acrylamides', 10),
#  ('simulations', 10),
#  ('zinc', 10),
#  ('sidechains', 10),
#  ('away', 10),
#  ('useful', 10),
#  ('john', 10),
#  ('x0689', 10),
#  ('beta', 10),
#  ('nanomolar', 10),
#  ('c1c', 10),
#  ('mimic', 10),
#  ('5rey', 10),
#  ('5ren', 10),
#  ('5rfg', 10),
#  ('crystals', 10),
#  ('privileged', 10),
#  ('antiplasmodial', 10),
#  ('chembridge', 10),
#  ('vast', 10),
#  ('3-amino-pyridine', 10),
#  ('substructure', 10),
#  ('try-uni-2eddb1ff-7', 10),
#  ('aiddt', 10),
#  ('how-it-works', 10),
#  ('-13', 10),
#  ('abdel', 10),
#  ('ghani', 10),
#  ('introduction', 9),
#  ('aliphatic', 9),
#  ('central', 9),
#  ('enable', 9),
#  ('attach', 9),
#  ('probe', 9),
#  ('decided', 9),
#  ('clashes', 9),
#  ('nearby', 9),
#  ('rational', 9),
#  ('synthetically', 9),
#  ('worth', 9),
#  ('chimera', 9),
#  ('screened', 9),
#  ('sequence', 9),
#  ('greater', 9),
#  ('isostere', 9),
#  ('ch2', 9),
#  ('proposing', 9),
#  ('chloride', 9),
#  ('possibility', 9),
#  ('r-group', 9),
#  ('sulfur', 9),
#  ('assume', 9),
#  ('drug-like', 9),
#  ('inf', 9),
#  ('crystallography', 9),
#  ('having', 9),
#  ('reduced', 9),
#  ('peptidomimetic', 9),
#  ('strategy', 9),
#  ('laboratory', 9),
#  ('in-development', 9),
#  ('incorporated', 9),
#  ('optimize', 9),
#  ('optimized', 9),
#  ('minor', 9),
#  ('synthesizable', 9),
#  ('remaining', 9),
#  ('pyrazole', 9),
#  ('lowest', 9),
#  ('negative', 9),
#  ('glu', 9),
#  ('coronavirus', 9),
#  ('sulfone', 9),
#  ('med', 9),
#  ('qed', 9),
#  ('sdf', 9),
#  ('server', 9),
#  ('input', 9),
#  ('x_0072', 9),
#  ('binder', 9),
#  ('subset', 9),
#  ('interacts', 9),
#  ('specificity', 9),
#  ('angles', 9),
#  ('lipinski', 9),
#  ('estimated', 9),
#  ('cc2', 9),
#  ('optimal', 9),
#  ('attempts', 9),
#  ('chodera', 9),
#  ('occupies', 9),
#  ('stereochemistry', 9),
#  ('replication', 9),
#  ('conformers', 9),
#  ('methylene', 9),
#  ('code', 9),
#  ('algo', 9),
#  ('6y2f', 9),
#  ('non-native', 9),
#  ('forum', 9),
#  ('tethered', 9),
#  ('6y2g', 9),
#  ('alerts', 9),
#  ('-10', 9),
#  ('hba', 9),
#  ('submit', 9),
#  ('pyrrolopyridine', 9),
#  ('5r82', 9),
#  ('fluorochem', 9),
#  ('superimposing', 8),
#  ('morpholine', 8),
#  ('variants', 8),
#  ('modes', 8),
#  ('bioisosteres', 8),
#  ('lock', 8),
#  ('carboxylic', 8),
#  ('recently', 8),
#  ('assuming', 8),
#  ('hypothesis', 8),
#  ('nice', 8),
#  ('excellent', 8),
#  ('variant', 8),
#  ('axial', 8),
#  ('occupied', 8),
#  ('electrophile', 8),
#  ('basicity', 8),
#  ('micromolar', 8),
#  ('fused', 8),
#  ('co-crystalized', 8),
#  ('conventional', 8),
#  ('supervised', 8),
#  ('fashion', 8),
#  ('clash', 8),
#  ('probing', 8),
#  ('violations', 8),
#  ('cheminformatics', 8),
#  ('perfectly', 8),
#  ('extending', 8),
#  ('repositioning', 8),
#  ('pairwise', 8),
#  ('top-ranked', 8),
#  ('arbitrarily', 8),
#  ('thresholds', 8),
#  ('phe', 8),
#  ('population', 8),
#  ('changing', 8),
#  ('ligtmap', 8),
#  ('cis', 8),
#  ('x0395', 8),
#  ('existing', 8),
#  ('acetamide', 8),
#  ('google', 8),
#  ('ortho', 8),
#  ('antivirals', 8),
#  ('literature', 8),
#  ('schrodinger', 8),
#  ('possibilities', 8),
#  ('e189', 8),
#  ('shift', 8),
#  ('aryl', 8),
#  ('bioavailability', 8),
#  ('filters', 8),
#  ('role', 8),
#  ('remdesivir', 8),
#  ('feature', 8),
#  ('c145', 8),
#  ('follow-up', 8),
#  ('cyclohexane', 8),
#  ('zhang', 8),
#  ('generations', 8),
#  ('vonoprazan', 8),
#  ('later', 8),
#  ('intended', 8),
#  ('ebselen', 8),
#  ('swissadme', 8),
#  ('gb-ga', 8),
#  ('prior', 8),
#  ('access', 8),
#  ('subunit', 8),
#  ('c-c', 8),
#  ('5rel', 8),
#  ('aligned', 8),
#  ('define', 8),
#  ('goldplp', 8),
#  ('chlorine', 8),
#  ('express', 8),
#  ('alex', 8),
#  ('x3077', 8),
#  ('fep', 8),
#  ('wiki', 8),
#  ('beta-lactam', 8),
#  ('reductive', 8),
#  ('amination', 8),
#  ('-14', 8),
#  ('heterocycle', 7),
#  ('x0540', 7),
#  ('imidazole', 7),
#  ('bridge', 7),
#  ('h41', 7),
#  ('medchem', 7),
#  ('replacing', 7),
#  ('produced', 7),
#  ('dimer', 7),
#  ('respiratory', 7),
#  ('obviously', 7),
#  ('modelled', 7),
#  ('tetrahydroquinoline', 7),
#  ('preferred', 7),
#  ('s-attached', 7),
#  ('pro168', 7),
#  ('accommodate', 7),
#  ('trial', 7),
#  ('partial', 7),
#  ('lower', 7),
#  ('clogp', 7),
#  ('details', 7),
#  ('graduate', 7),
#  ('jens', 7),
#  ('vanderbilt', 7),
#  ('released', 7),
#  ('served', 7),
#  ('feed-forward', 7),
#  ('scorer', 7),
#  ('perturbed', 7),
#  ('monte', 7),
#  ('carlo', 7),
#  ('metropolis', 7),
#  ('alchemical', 7),
#  ('transformations', 7),
#  ('unstable', 7),
#  ('non-drug-like', 7),
#  ('linkfragments', 7),
#  ('selectively', 7),
#  ('intentionally', 7),
#  ('top-scoring', 7),
#  ('instances', 7),
#  ('well-populated', 7),
#  ('nomenclature', 7),
#  ('receptors', 7),
#  ('descriptors', 7),
#  ('metrics', 7),
#  ('acids', 7),
#  ('accepted', 7),
#  ('assumed', 7),
#  ('fail', 7),
#  ('rank', 7),
#  ('probability', 7),
#  ('discriminate', 7),
#  ...]

# %%
# make word cloud
with open('wordcloud.txt', 'w') as w:
    w.write('\n'.join([' '.join([k] * wordbag[k]) for k in wordbag if wordbag[k] > 20 and k != 'nan']))

# %% [markdown]
# ## Find enrichment

# %%
from typing import Dict

def get_data_on_term(term:str) -> Dict[str, float]:
    if term == 'by-eye':
        term = 'by eye'
    subtable = postera.loc[postera.rationale.str.contains(term, case=False)]
    return {'term': term, **get_data_on_table(subtable)}
    
def get_data_on_table(table:pd.DataFrame) -> Dict[str, float]:
    data = {}
    data['N'] = len(table)
    if data['N'] == 0:
        print(f'Table failed!')
        return data
    # ordered
    ordered = table.ORDERED.value_counts()
    data['N_ordered'] = ordered[True] if True in ordered else 0
    data['N_not_ordered'] = ordered[False] if False in ordered else 0
    data['freq_ordered (of total)'] = round(data['N_ordered'] / data['N'], 4)
    # made
    made = table.MADE.value_counts()
    data['N_made'] = made[True] if True in made else 0
    data['N_not_made'] = made[False] if False in made else 0
    data['freq_made (of total)'] = round(data['N_made'] / data['N'], 4)
    data['freq_made (of ordered)'] = round(data['N_made']/data['N_ordered'], 4) if data['N_ordered'] != 0 else 0
    # xstalised
    xstalised = table.structure_ID.value_counts().sum()
    data['N_crystallised'] = xstalised
    data['N_not_crystallised'] = data['N'] - xstalised
    data['freq_crystallised (of total)'] = round(xstalised/data['N'], 4)
    data['freq_crystallised (of made)'] = round(xstalised/data['N_made'], 4) if data['N_made'] != 0 else 0
    # assayed
    assayed = table.ASSAYED.value_counts()
    data['N_assayed'] = assayed[True] if True in assayed else 0
    data['N_not_assayed'] = assayed[False] if False in assayed else 0
    data['freq_assayed (of total)'] = round(data['N_assayed'] / data['N'], 4)
    data['freq_assayed (of made)'] = round(data['N_assayed']/data['N_made'], 4)  if data['N_made'] != 0 else 0
    # return
    return data

# %%
# pd.DataFrame({'term': pd.Series(data = list(wordbag.keys()), dtype=str),
#               'count': pd.Series(data = list(wordbag.values()), dtype=int)})

# %%
data = [get_data_on_term(term) for term in wordbag]

term_table = pd.DataFrame(data)
term_table
# Out:
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
# Table failed!
#              term    N  N_ordered  N_not_ordered  freq_ordered (of total)  \
# 0         nitrile  623       24.0          599.0                   0.0385
# 1           x0305  216       68.0          148.0                   0.3148
# 2     superimpose   56       13.0           43.0                   0.2321
# 3           x1249  188       34.0          154.0                   0.1809
# 4           x0434  375       77.0          298.0                   0.2053
# ...           ...  ...        ...            ...                      ...
# 5900      removal    0        NaN            NaN                      NaN
# 5901      t-butyl    0        NaN            NaN                      NaN
# 5902       plenty    0        NaN            NaN                      NaN
# 5903          raw  151        4.0          147.0                   0.0265
# 5904    abolishes    0        NaN            NaN                      NaN
#
#       N_made  N_not_made  freq_made (of total)  freq_made (of ordered)  \
# 0       18.0       605.0                0.0289                  0.7500
# 1       39.0       177.0                0.1806                  0.5735
# 2        5.0        51.0                0.0893                  0.3846
# 3       22.0       166.0                0.1170                  0.6471
# 4       52.0       323.0                0.1387                  0.6753
# ...      ...         ...                   ...                     ...
# 5900     NaN         NaN                   NaN                     NaN
# 5901     NaN         NaN                   NaN                     NaN
# 5902     NaN         NaN                   NaN                     NaN
# 5903     1.0       150.0                0.0066                  0.2500
# 5904     NaN         NaN                   NaN                     NaN
#
#       N_crystallised  N_not_crystallised  freq_crystallised (of total)  \
# 0                4.0               619.0                        0.0064
# 1                6.0               210.0                        0.0278
# 2                0.0                56.0                        0.0000
# 3                4.0               184.0                        0.0213
# 4               12.0               363.0                        0.0320
# ...              ...                 ...                           ...
# 5900             NaN                 NaN                           NaN
# 5901             NaN                 NaN                           NaN
# 5902             NaN                 NaN                           NaN
# 5903             0.0               151.0                        0.0000
# 5904             NaN                 NaN                           NaN
#
#       freq_crystallised (of made)  N_assayed  N_not_assayed  \
# 0                          0.2222       18.0          605.0
# 1                          0.1538       39.0          177.0
# 2                          0.0000        5.0           51.0
# 3                          0.1818       22.0          166.0
# 4                          0.2308       52.0          323.0
# ...                           ...        ...            ...
# 5900                          NaN        NaN            NaN
# 5901                          NaN        NaN            NaN
# 5902                          NaN        NaN            NaN
# 5903                       0.0000        1.0          150.0
# 5904                          NaN        NaN            NaN
#
#       freq_assayed (of total)  freq_assayed (of made)
# 0                      0.0289                     1.0
# 1                      0.1806                     1.0
# 2                      0.0893                     1.0
# 3                      0.1170                     1.0
# 4                      0.1387                     1.0
# ...                       ...                     ...
# 5900                      NaN                     NaN
# 5901                      NaN                     NaN
# 5902                      NaN                     NaN
# 5903                   0.0066                     1.0
# 5904                      NaN                     NaN
#
# [5905 rows x 17 columns]

# %%
term_table.to_csv(f'{gitrepo_folder}/term_frequencies.csv')

# %%
data.append({'term': '<TALLY>', **get_data_on_table(postera)})
term_table = pd.DataFrame(data)

# %%
tally_row = term_table.loc[term_table.term == '<TALLY>'].iloc[0]
tally_row

term_table = term_table[['term', 'N', 
                         'N_ordered', 'N_not_ordered',
                         'N_made', 'N_not_made',
                         'N_assayed', 'N_not_assayed',
                         'N_crystallised', 'N_not_crystallised',
                         'freq_ordered (of total)',
                         'freq_made (of total)', 'freq_assayed (of total)', 'freq_crystallised (of total)',
                         'freq_made (of ordered)', 'freq_assayed (of made)', 'freq_crystallised (of made)'
                        ]]

# %%
from scipy.stats import chisquare, nbinom, fisher_exact

new_columns = {}
for field in ('ordered', 'made',  'assayed', 'crystallised'):
    fisherise = lambda row: fisher_exact([[row.N, row[f'N_{field}'] ],
                                          [tally_row.N, tally_row[f'N_{field}'] ]
                                         ])[1] if str(row[f'N_{field}']) != 'nan' else float('nan')
    chiify = lambda row: chisquare(f_obs=[row.N, row[f'N_{field}']],
                                   f_exp=[tally_row.N, tally_row[f'N_{field}'] ]).pvalue
    new_columns[f'fisher_p_{field}'] = term_table.apply(fisherise,axis=1)
    new_columns[f'χ2_p_{field}'] = term_table.apply(chiify,axis=1)

term_table = term_table.assign(**new_columns)

# %%
import numpy as np

new_columns = {}
for field in ('freq_ordered (of total)',
              'freq_made (of total)',
              'freq_assayed (of total)', 
              'freq_crystallised (of total)',
              'freq_made (of ordered)', 
              'freq_assayed (of made)',
              'freq_crystallised (of made)'):
    new_columns[f'log2_{field}'] = np.log2(term_table[field].values / tally_row[field])

term_table = term_table.assign(**new_columns)
# Out:
# /Users/matteo/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in log2
#   # This is added back by InteractiveShellApp.init_path()

# %%
term_table.to_csv(f'{gitrepo_folder}/terms.csv')

# %%
## Crystallised

total = len(term_table)
crystal = term_table.loc[term_table.fisher_p_crystallised < 0.05/total]\
                    .sort_values('freq_crystallised (of total)', ascending=False)\
                    .head(100)
crystal.to_csv(f'{gitrepo_folder}/Top100_terms_enchriched_for_crystallisation.csv')
crystal
# Out:
#                     term     N  N_ordered  N_not_ordered  N_made  N_not_made  \
# 2741            moonshot   290       57.0          233.0    34.0       256.0
# 3639                 cid   378       51.0          327.0    28.0       350.0
# 406          submissions   269       69.0          200.0    45.0       224.0
# 4398                shot   545       61.0          484.0    37.0       508.0
# 3643  try-uni-714a760b-6    74       55.0           19.0    48.0        26.0
# ...                  ...   ...        ...            ...     ...         ...
# 83              cysteine  1384        7.0         1377.0     4.0      1380.0
# 2099          calculated  2526        3.0         2523.0     1.0      2525.0
# 1960           proteases  1274        1.0         1273.0     1.0      1273.0
# 1959         calculation   770       34.0          736.0    32.0       738.0
# 1300                mers  3018        6.0         3012.0     1.0      3017.0
#
#       N_assayed  N_not_assayed  N_crystallised  N_not_crystallised  ...  \
# 2741       33.0          257.0            98.0               192.0  ...
# 3639       27.0          351.0            93.0               285.0  ...
# 406        45.0          224.0            52.0               217.0  ...
# 4398       36.0          509.0            98.0               447.0  ...
# 3643       48.0           26.0            12.0                62.0  ...
# ...         ...            ...             ...                 ...  ...
# 83          4.0         1380.0             0.0              1384.0  ...
# 2099        1.0         2525.0             0.0              2526.0  ...
# 1960        1.0         1273.0             0.0              1274.0  ...
# 1959       32.0          738.0             0.0               770.0  ...
# 1300        1.0         3017.0             0.0              3018.0  ...
#
#       χ2_p_assayed  fisher_p_crystallised  χ2_p_crystallised  \
# 2741           0.0           2.503830e-76                0.0
# 3639           0.0           1.402962e-62                0.0
# 406            0.0           1.114159e-32                0.0
# 4398           0.0           6.609641e-55                0.0
# 3643           0.0           2.895993e-08                0.0
# ...            ...                    ...                ...
# 83             0.0           4.380464e-10                0.0
# 2099           0.0           2.405097e-17                0.0
# 1960           0.0           2.538007e-09                0.0
# 1959           0.0           7.994828e-06                0.0
# 1300           0.0           1.844121e-20                0.0
#
#       log2_freq_ordered (of total)  log2_freq_made (of total)  \
# 2741                      0.691934                   0.382580
# 3639                      0.148561                  -0.278848
# 406                       1.075630                   0.896044
# 4398                     -0.121119                  -0.404910
# 3643                      2.610421                   2.850936
# ...                            ...                        ...
# 83                       -4.576688                  -4.954196
# 2099                     -6.664151                  -7.812177
# 1960                     -7.249113                  -6.812177
# 1959                     -1.461211                  -1.111738
# 1300                     -5.927185                  -8.227215
#
#       log2_freq_assayed (of total)  log2_freq_crystallised (of total)  \
# 2741                      0.367650                           4.321501
# 3639                     -0.304855                           3.863563
# 406                       0.923587                           3.515746
# 4398                     -0.416128                           3.411298
# 3643                      2.878478                           3.262679
# ...                            ...                                ...
# 83                       -4.926654                               -inf
# 2099                     -7.784635                               -inf
# 1960                     -6.784635                               -inf
# 1959                     -1.084195                               -inf
# 1300                     -8.199672                               -inf
#
#       log2_freq_made (of ordered)  log2_freq_assayed (of made)  \
# 2741                    -0.307880                    -0.015376
# 3639                    -0.427596                    -0.024771
# 406                     -0.179088                     0.027675
# 4398                    -0.283657                    -0.011813
# 3643                     0.241083                     0.027675
# ...                           ...                          ...
# 83                      -0.369902                     0.027675
# 2099                    -1.147581                     0.027675
# 1960                     0.437526                     0.027675
# 1959                     0.350099                     0.027675
# 1300                    -2.147148                     0.027675
#
#       log2_freq_crystallised (of made)
# 2741                          3.933869
# 3639                          4.138390
# 406                           2.615241
# 4398                          3.811828
# 3643                          0.406598
# ...                                ...
# 83                                -inf
# 2099                              -inf
# 1960                              -inf
# 1959                              -inf
# 1300                              -inf
#
# [100 rows x 32 columns]

# %%
## Crystallised 2

total = len(term_table)
crystal = term_table.loc[term_table.fisher_p_crystallised < 0.05/total]\
                    .sort_values('freq_crystallised (of made)', ascending=False)\
                    .head(100)
crystal.to_csv(f'{gitrepo_folder}/Top100_terms_enchriched_for_crystallisation_of_made.csv')
crystal
# Out:
#              term     N  N_ordered  N_not_ordered  N_made  N_not_made  \
# 3342        batch  1027       31.0          996.0    14.0      1013.0
# 3639          cid   378       51.0          327.0    28.0       350.0
# 2741     moonshot   290       57.0          233.0    34.0       256.0
# 4398         shot   545       61.0          484.0    37.0       508.0
# 3866     treweren  4207        5.0         4202.0     5.0      4202.0
# ...           ...   ...        ...            ...     ...         ...
# 479       primary  1338        5.0         1333.0     5.0      1333.0
# 1960    proteases  1274        1.0         1273.0     1.0      1273.0
# 136        centre  2966       23.0         2943.0    20.0      2946.0
# 970        served  3256       27.0         3229.0    20.0      3236.0
# 1959  calculation   770       34.0          736.0    32.0       738.0
#
#       N_assayed  N_not_assayed  N_crystallised  N_not_crystallised  ...  \
# 3342       14.0         1013.0            91.0               936.0  ...
# 3639       27.0          351.0            93.0               285.0  ...
# 2741       33.0          257.0            98.0               192.0  ...
# 4398       36.0          509.0            98.0               447.0  ...
# 3866        4.0         4203.0             9.0              4198.0  ...
# ...         ...            ...             ...                 ...  ...
# 479         5.0         1333.0             0.0              1338.0  ...
# 1960        1.0         1273.0             0.0              1274.0  ...
# 136        20.0         2946.0             0.0              2966.0  ...
# 970        20.0         3236.0             0.0              3256.0  ...
# 1959       32.0          738.0             0.0               770.0  ...
#
#       χ2_p_assayed  fisher_p_crystallised  χ2_p_crystallised  \
# 3342           0.0           4.283002e-30                0.0
# 3639           0.0           1.402962e-62                0.0
# 2741           0.0           2.503830e-76                0.0
# 4398           0.0           6.609641e-55                0.0
# 3866           0.0           3.229300e-17                0.0
# ...            ...                    ...                ...
# 479            0.0           1.114396e-09                0.0
# 1960           0.0           2.538007e-09                0.0
# 136            0.0           3.171292e-20                0.0
# 970            0.0           7.755804e-22                0.0
# 1959           0.0           7.994828e-06                0.0
#
#       log2_freq_ordered (of total)  log2_freq_made (of total)  \
# 3342                     -2.010709                  -2.724714
# 3639                      0.148561                  -0.278848
# 2741                      0.691934                   0.382580
# 4398                     -0.121119                  -0.404910
# 3866                     -6.664151                  -6.227215
# ...                            ...                        ...
# 479                      -5.039660                  -4.602724
# 1960                     -7.249113                  -6.812177
# 136                      -3.963711                  -3.746088
# 970                      -3.874074                  -3.881440
# 1959                     -1.461211                  -1.111738
#
#       log2_freq_assayed (of total)  log2_freq_crystallised (of total)  \
# 3342                     -2.697172                           2.390283
# 3639                     -0.304855                           3.863563
# 2741                      0.367650                           4.321501
# 4398                     -0.416128                           3.411298
# 3866                     -6.462707                          -3.008562
# ...                            ...                                ...
# 479                      -4.575181                               -inf
# 1960                     -6.784635                               -inf
# 136                      -3.718546                               -inf
# 970                      -3.853898                               -inf
# 1959                     -1.084195                               -inf
#
#       log2_freq_made (of ordered)  log2_freq_assayed (of made)  \
# 3342                    -0.709357                     0.027675
# 3639                    -0.427596                    -0.024771
# 2741                    -0.307880                    -0.015376
# 4398                    -0.283657                    -0.011813
# 3866                     0.437526                    -0.294253
# ...                           ...                          ...
# 479                      0.437526                     0.027675
# 1960                     0.437526                     0.027675
# 136                      0.235949                     0.027675
# 970                      0.004487                     0.027675
# 1959                     0.350099                     0.027675
#
#       log2_freq_crystallised (of made)
# 3342                          5.107038
# 3639                          4.138390
# 2741                          3.933869
# 4398                          3.811828
# 3866                          3.254595
# ...                                ...
# 479                               -inf
# 1960                              -inf
# 136                               -inf
# 970                               -inf
# 1959                              -inf
#
# [100 rows x 32 columns]

# %%
headers = ['term','N','N_ordered','N_made','N_assayed','N_crystallised','fisher_p_made','fisher_p_crystallised','log2_freq_made (of total)','log2_freq_crystallised (of total)','log2_freq_crystallised (of made)']
term_table.loc[term_table.term.isin(['dock', 'score', 'merge', 'enumerate', 'calculate', 'by eye', 'fragalysis'])][headers]#.to_markdown()
# Out:
#             term     N  N_ordered  N_made  N_assayed  N_crystallised  \
# 15         merge   362       52.0    21.0       21.0             7.0
# 20    fragalysis    69        5.0     4.0        3.0             4.0
# 44        by eye  1795      124.0    84.0       84.0            16.0
# 1496        dock  4571      255.0   188.0      187.0            23.0
# 2744   enumerate   127       25.0     4.0        4.0             1.0
#
#       fisher_p_made  fisher_p_crystallised  log2_freq_made (of total)  \
# 15     5.815363e-02           6.787069e-01                  -0.632268
# 20     5.225328e-01           3.473028e-02                  -0.632268
# 44     9.269836e-10           9.114118e-03                  -0.941813
# 1496   3.237964e-26           1.330122e-10                  -1.129183
# 2744   2.486778e-02           7.270644e-01                  -1.512969
#
#       log2_freq_crystallised (of total)  log2_freq_crystallised (of made)
# 15                             0.191578                          0.821492
# 20                             1.779030                          2.406598
# 44                            -0.925146                          0.014461
# 1496                          -1.757023                         -0.624905
# 2744                          -1.097099                          0.406598

# %%
import shutil, os
from git import Repo
shutil.copy('rationale analysis.ipynb', f'{gitrepo_folder}/rationale_analysis.ipynb')

repo = Repo(gitrepo_folder)
repo.index.add(os.listdir(gitrepo_folder))   
repo.index.commit(':truck: data')
repo.remotes.origin.push()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-3e79e1474775> in <module>
#       1 import shutil, os
#       2 from git import Repo
# ----> 3 shutils.copy('rationale analysis.ipynb', f'{gitrepo_folder}/rationale_analysis.ipynb')
#       4
#       5 repo = Repo(gitrepo_folder)
#
# NameError: name 'shutils' is not defined
