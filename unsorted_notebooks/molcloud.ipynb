# %%
import molcloud
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 10))

# %%
import pandas as pd

moonshot = pd.read_pickle('moonshot_submissions.p')

# %%
molcloud.plot_molcloud(moonshot.loc[moonshot['Structure ID'] != ''].SMILES,
                       node_size=0.2,
                      background_color='#FFFFFF')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 311/311 [00:15<00:00, 19.77it/s]
